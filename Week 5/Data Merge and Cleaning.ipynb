# %%
import pandas as pd 
import os

# %% [markdown]
# # Merge all files in one

# %%
files = [file for file in os.listdir('../Datasets/Week5/')]

dft = pd.DataFrame()

for file in files:
    df = pd.read_csv('../Datasets/Week5/'+file)
    dft = pd.concat([dft,df])

    
# Save all data in one file, na_rep='<value to replace>' index=<bool>

dft.to_csv('merged_data.csv', index=False, na_rep='(missing)')

# %%
df = pd.read_csv('merged_data.csv')
df.head()
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     176558        USB-C Charging Cable                2      11.95
# 1  (missing)                   (missing)        (missing)  (missing)
# 2     176559  Bose SoundSport Headphones                1      99.99
# 3     176560                Google Phone                1        600
# 4     176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1       (missing)                             (missing)
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# # Clean up the data

# %%
df.loc[df['Product'] == '(missing)']
# Out:
#          Order ID    Product Quantity Ordered Price Each Order Date  \
# 1       (missing)  (missing)        (missing)  (missing)  (missing)
# 356     (missing)  (missing)        (missing)  (missing)  (missing)
# 735     (missing)  (missing)        (missing)  (missing)  (missing)
# 1433    (missing)  (missing)        (missing)  (missing)  (missing)
# 1553    (missing)  (missing)        (missing)  (missing)  (missing)
# ...           ...        ...              ...        ...        ...
# 185176  (missing)  (missing)        (missing)  (missing)  (missing)
# 185438  (missing)  (missing)        (missing)  (missing)  (missing)
# 186042  (missing)  (missing)        (missing)  (missing)  (missing)
# 186548  (missing)  (missing)        (missing)  (missing)  (missing)
# 186826  (missing)  (missing)        (missing)  (missing)  (missing)
#
#        Purchase Address
# 1             (missing)
# 356           (missing)
# 735           (missing)
# 1433          (missing)
# 1553          (missing)
# ...                 ...
# 185176        (missing)
# 185438        (missing)
# 186042        (missing)
# 186548        (missing)
# 186826        (missing)
#
# [545 rows x 6 columns]

# %%
df = df[df['Product'] != '(missing)'] # Remove (missing) data

# %%
df = df[df['Product'] != 'Product'] # Remove trash data

# %% [markdown]
# # Save and Load again

# %%
df.to_csv('merged_data.csv', index=False, na_rep='(missing)')

# %%
df = pd.read_csv('merged_data.csv')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# # Reorder the data

# %%
df['Month'] = df['Order Date'].str[:2]
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
df.dtypes
# Out:
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# dtype: object

# %%
df['Day'] = df['Order Date'].str[3:5]
df['Day'] = df['Day'].astype('int32')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Day
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   19
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4    7
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   30

# %%
df['Year'] = df['Order Date'].str[6:9]
df['Year'] = df['Year'].astype('int32')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Day  Year
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   19    19
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4    7    19
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   30    19

# %%
df['Hour'] = df['Order Date'].str[9:14]
df['Hour'] = df['Hour'].astype('str')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Day  Year  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   19    19
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4    7    19
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   30    19
#
#     Hour
# 0  08:46
# 1  22:30
# 2  14:38
# 3  14:38
# 4  09:27

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Order ID                     int64
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int32
# Day                          int32
# Year                         int32
# Hour                        object
# dtype: object

# %%
df[['Street','City','Code']] = df['Purchase Address'].str.split(',', expand=True)
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  Day  Year  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   19    19
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4    7    19
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   30    19
#
#     Hour           Street          City       Code
# 0  08:46       917 1st St        Dallas   TX 75001
# 1  22:30  682 Chestnut St        Boston   MA 02215
# 2  14:38    669 Spruce St   Los Angeles   CA 90001
# 3  14:38    669 Spruce St   Los Angeles   CA 90001
# 4  09:27       333 8th St   Los Angeles   CA 90001

# %%
df['Sales'] = df['Price Each'] * df['Quantity Ordered']
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  Day  Year  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   19    19
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4    7    19
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12    19
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   30    19
#
#     Hour           Street          City       Code   Sales
# 0  08:46       917 1st St        Dallas   TX 75001   23.90
# 1  22:30  682 Chestnut St        Boston   MA 02215   99.99
# 2  14:38    669 Spruce St   Los Angeles   CA 90001  600.00
# 3  14:38    669 Spruce St   Los Angeles   CA 90001   11.99
# 4  09:27       333 8th St   Los Angeles   CA 90001   11.99

# %% [markdown]
# # Save again with all data

# %%
df.to_csv('merged_data.csv', index=False)

# %% [markdown]
# # Validate all our data

# %%
df = pd.read_csv('merged_data.csv')
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#             Order Date                      Purchase Address  Month  Day  \
# 0  2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   19
# 1  2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4    7
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12
# 4  2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   30
#
#    Year   Hour           Street          City       Code   Sales
# 0    19  08:46       917 1st St        Dallas   TX 75001   23.90
# 1    19  22:30  682 Chestnut St        Boston   MA 02215   99.99
# 2    19  14:38    669 Spruce St   Los Angeles   CA 90001  600.00
# 3    19  14:38    669 Spruce St   Los Angeles   CA 90001   11.99
# 4    19  09:27       333 8th St   Los Angeles   CA 90001   11.99

# %%
df.dtypes
# Out:
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# Day                   int64
# Year                  int64
# Hour                 object
# Street               object
# City                 object
# Code                 object
# Sales               float64
# dtype: object
